# %%
import pandas as pd

# %%
nf1 = pd.read_csv('netflix_titles.csv')

# %%
nf1
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
nf1.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
 nf1.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
nf1.shape
# Out:
# (8807, 12)

# %%
nf1.size
# Out:
# 105684

# %%
nf1.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
nf1.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
nf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
nf1.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
nf1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
nf1[nf1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
nf1.drop_duplicates(inplace = True)

# %%
nf1.shape
# Out:
# (8807, 12)

# %%
nf1.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
nf1.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(nf1.isnull())

# %%
nf1['title'].isin(['Sacred Games'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: title, Length: 8807, dtype: bool

# %%
nf1[nf1['title'].isin(['Sacred Games'])]
# Out:
#      show_id     type         title                              director  \
# 3589   s3590  TV Show  Sacred Games  Vikramaditya Motwane, Anurag Kashyap
#
#                                                    cast               country  \
# 3589  Saif Ali Khan, Nawazuddin Siddiqui, Radhika Ap...  India, United States
#
#            date_added  release_year rating   duration  \
# 3589  August 15, 2019          2019  TV-MA  2 Seasons
#
#                                               listed_in  \
# 3589  Crime TV Shows, International TV Shows, TV Dramas
#
#                                             description
# 3589  A link in their pasts leads an honest cop to a...

# %%
nf1['title'].str.contains('Peaky Blinders')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: title, Length: 8807, dtype: bool

# %%
nf1[nf1['title'].str.contains('Peaky Blinders')]
# Out:
#      show_id     type           title director  \
# 3452   s3453  TV Show  Peaky Blinders      NaN
#
#                                                    cast         country  \
# 3452  Cillian Murphy, Sam Neill, Helen McCrory, Paul...  United Kingdom
#
#            date_added  release_year rating   duration  \
# 3452  October 4, 2019          2019  TV-MA  5 Seasons
#
#                                               listed_in  \
# 3452  British TV Shows, Crime TV Shows, Internationa...
#
#                                             description
# 3452  A notorious gang in 1919 Birmingham, England, ...

# %%
 nf1.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
nf1['Date_N']=pd.to_datetime(nf1['date_added'])

# %%
nf1.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
nf1.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
nf1['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
nf1['Date_N'].dt.year.value_counts().plot(kind='bar')

# %%
nf1.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
nf1.rename(columns = {'type':'Category',
'title':'TITLE'},inplace=True)

# %%
nf1.head(2)
# Out:
#   show_id Category                 TITLE         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
nf1.groupby('Category')

# %%
nf1.groupby('Category').Category.count()
# Out:
# Category
# Movie      6131
# TV Show    2676
# Name: Category, dtype: int64

# %%
nf1.groupby('release_year').release_year.count()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: release_year, Length: 74, dtype: int64

# %%
sns.countplot(nf1['Category'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
nf1['YEAR']=nf1['Date_N'].dt.year

# %%
nf1.head(2)
# Out:
#   show_id Category                 TITLE         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    YEAR
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
(nf1['Category']== 'Movie') & (nf1['YEAR']==2020)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805     True
# 8806    False
# Length: 8807, dtype: bool

# %%
nf1[(nf1['Category']== 'Movie') & (nf1['YEAR']==2020)]
# Out:
#      show_id Category                                TITLE  \
# 1470   s1471    Movie                     Alaska Is a Drag
# 1471   s1472    Movie                Best of Stand-Up 2020
# 1472   s1473    Movie                         Bobby Jasoos
# 1474   s1475    Movie                        Tarung Sarung
# 1475   s1476    Movie               Too Handsome to Handle
# ...      ...      ...                                  ...
# 8742   s8743    Movie                       Wild Wild West
# 8743   s8744    Movie                             Wildlife
# 8745   s8746    Movie  Willy Wonka & the Chocolate Factory
# 8764   s8765    Movie                           Wyatt Earp
# 8805   s8806    Movie                                 Zoom
#
#                        director  \
# 1470               Shaz Bennett
# 1471                        NaN
# 1472               Samar Shaikh
# 1474            Archie Hekagery
# 1475  Sabrina Rochelle Kalangie
# ...                         ...
# ...

# %%
nf1[(nf1['Category']== 'Movie') & (nf1['YEAR']==2020)].head(2)
# Out:
#      show_id Category                  TITLE      director  \
# 1470   s1471    Movie       Alaska Is a Drag  Shaz Bennett
# 1471   s1472    Movie  Best of Stand-Up 2020           NaN
#
#                                                    cast        country  \
# 1470  Martin L. Washington Jr., Maya Washington, Mat...  United States
# 1471  Jerry Seinfeld, Leslie Jones, Taylor Tomlinson...            NaN
#
#              date_added  release_year rating duration             listed_in  \
# 1470  December 31, 2020          2017  TV-MA   83 min  Dramas, LGBTQ Movies
# 1471  December 31, 2020          2020  TV-MA   77 min       Stand-Up Comedy
#
#                                             description     Date_N    YEAR
# 1470  Tormented by bullies, an aspiring drag star wo... 2020-12-31  2020.0
# 1471  From Jerry Seinfeld to Leslie Jones, Kevin Har... 2020-12-31  2020.0

# %%
(nf1['Category']=='TV Show') & (nf1['country']=='India')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
nf1[(nf1['Category']=='TV Show') & (nf1['country']=='India')]['TITLE']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: TITLE, Length: 79, dtype: object

# %%
nf1.head(1)
# Out:
#   show_id Category                 TITLE         director cast        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description     Date_N    YEAR
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0

# %%
nf1.groupby('director')

# %%
nf1['director'].value_counts()
# Out:
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: director, Length: 4528, dtype: int64

# %%
nf1['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
nf1.head(
  
)
# Out:
#   show_id Category                  TITLE         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
 (nf1['Category']=='Movie') & (nf1['country']=='United Kingdom')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
nf1[(nf1['Category']=='Movie') & (nf1['country']=='United Kingdom')]
# Out:
#      show_id Category                                TITLE  \
# 233     s234    Movie                          Count Me In
# 292     s293    Movie                              Quartet
# 304     s305    Movie  Lady Boss: The Jackie Collins Story
# 402     s403    Movie      The Last Letter From Your Lover
# 589     s590    Movie                             Red Joan
# ...      ...      ...                                  ...
# 8732   s8733    Movie                        White Chamber
# 8733   s8734    Movie                         White Island
# 8737   s8738    Movie           Why Are We Getting So Fat?
# 8744   s8745    Movie                             Williams
# 8786   s8787    Movie                         You Can Tutu
#
#                                     director  \
# 233                                  Mark Lo
# 292                           Dustin Hoffman
# 304                            Laura Fairrie
# 402                       Augustine Frizzell
# ...

# %%
nf1[(nf1['Category']=='Movie') & (nf1['country']=='United Kingdom')|(nf1['listed_in']=='Comedies')]
# Out:
#      show_id Category                          TITLE  \
# 27       s28    Movie                      Grown Ups
# 152     s153    Movie  Janoskians: Untold and Untrue
# 182     s183    Movie    Welcome Home Roscoe Jenkins
# 233     s234    Movie                    Count Me In
# 292     s293    Movie                        Quartet
# ...      ...      ...                            ...
# 8732   s8733    Movie                  White Chamber
# 8733   s8734    Movie                   White Island
# 8737   s8738    Movie     Why Are We Getting So Fat?
# 8744   s8745    Movie                       Williams
# 8786   s8787    Movie                   You Can Tutu
#
#                                     director  \
# 27                              Dennis Dugan
# 152                             Brett Weiner
# 182                           Malcolm D. Lee
# 233                                  Mark Lo
# 292                           Dustin Hoffman
# ...                                      ...
# ...

# %%
nf1.head(2)
# Out:
#   show_id Category                 TITLE         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    YEAR
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
(nf1['cast']=='Tom Cruise')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: cast, Length: 8807, dtype: bool

# %%
nf1[(nf1['cast']=='Gail Mabalane')]
# Out:
# Empty DataFrame
# Columns: [show_id, Category, TITLE, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, YEAR]
# Index: []

# %%
nf1['cast'].str.contains('Tom Cruise')
# Out:
# 0         NaN
# 1       False
# 2       False
# 3         NaN
# 4       False
#         ...
# 8802    False
# 8803      NaN
# 8804    False
# 8805    False
# 8806    False
# Name: cast, Length: 8807, dtype: object

# %%
nf2=nf1.dropna()

# %%
nf2.head(2)
# Out:
#   show_id Category                          TITLE         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description     Date_N    YEAR
# ...

# %%
nf2['cast'].str.contains('Tom Cruise')
# Out:
# 7       False
# 8       False
# 9       False
# 12      False
# 24      False
#         ...
# 8801    False
# 8802    False
# 8804    False
# 8805    False
# 8806    False
# Name: cast, Length: 5332, dtype: bool

# %%
nf2[nf2['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id Category     TITLE              director  \
# 341     s342    Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255    Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description     Date_N    YEAR
# 341   Through chance, history and divine interventio... 2021-08-01  2021.0
# 1254  Motivated by money, a selfish workaholic seeki... 2021-03-01  2021.0

# %%
nf1['rating'].nunique()
# Out:
# 17

# %%
 nf1.rename(columns={'rating':'Rating','listed_in':'genre'},inplace=True)

# %%
nf1['Rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
(nf1['Category']=='Movie') & (nf1['Rating']=='TV-14')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806     True
# Length: 8807, dtype: bool

# %%
nf1[(nf1['Category']=='Movie') & (nf1['Rating']=='TV-14')]
# Out:
#      show_id Category                                              TITLE  \
# 18       s19    Movie                                          Intrusion
# 24       s25    Movie                                              Jeans
# 30       s31    Movie                                    Ankahi Kahaniya
# 51       s52    Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 52       s53    Movie  InuYasha the Movie 3: Swords of an Honorable R...
# ...      ...      ...                                                ...
# 8772   s8773    Movie                              Yamla Pagla Deewana 2
# 8774   s8775    Movie                                          يوم الدين
# 8794   s8795    Movie                                             اشتباك
# 8799   s8800    Movie                                              Zenda
# 8806   s8807    Movie                                             Zubaan
#
#                                                director  \
# ...

# %%
nf1[(nf1['Category']=='Movie') & (nf1['Rating']=='TV-14') & (nf1['country']=='India')]
# Out:
#      show_id Category                  TITLE              director  \
# 24       s25    Movie                  Jeans            S. Shankar
# 105     s106    Movie       Angamaly Diaries  Lijo Jose Pellissery
# 114     s115    Movie                 Anjaam          Rahul Rawail
# 118     s119    Movie                Gurgaon         Shanker Raman
# 126     s127    Movie                Shikara    Vidhu Vinod Chopra
# ...      ...      ...                    ...                   ...
# 8770   s8771    Movie                Yaadein          Subhash Ghai
# 8771   s8772    Movie       Yaara O Dildaara    Ksshitij Chaudhary
# 8772   s8773    Movie  Yamla Pagla Deewana 2        Sangeeth Sivan
# 8799   s8800    Movie                  Zenda        Avadhoot Gupte
# 8806   s8807    Movie                 Zubaan           Mozez Singh
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %%
(nf1['Category']=='TV Show') & (nf1['Rating']=='R')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
nf1.head(2)
# Out:
#   show_id Category                 TITLE         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year Rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                              genre  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    YEAR
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
nf1.head(2)
# Out:
#   show_id Category                 TITLE         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year Rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                              genre  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    YEAR
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
nf1.rename(columns = {'type':'Category',
'title':'TITLE'},inplace=True)

# %%
nf1
# Out:
#      show_id Category                  TITLE         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
(nf1['Category']=='TV Show') & (nf1['Rating']=='R') & (nf1['release_year']>2018)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
nf1[(nf1['Category']=='TV Show') & (nf1['Rating']=='R') & (nf1['release_year']>2015)]
# Out:
#      show_id Category  TITLE director  \
# 7593   s7594  TV Show  Nobel      NaN
#
#                                                    cast country  \
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added  release_year Rating  duration  \
# 7593  December 10, 2016          2016      R  1 Season
#
#                                                 genre  \
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description     Date_N    YEAR
# 7593  A series of incidents in Afghanistan set compl... 2016-12-10  2016.0

# %%
nf1.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
nf1.duration.dtypes
# Out:
# dtype('O')

# %%
nf1[['Minutes', 'units']]=nf1['duration'].str.split(' ', expand=True)

# %%
nf1.head(2)
# Out:
#   show_id Category                 TITLE         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year Rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                              genre  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    YEAR  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes    units
# ...

# %%
nf1['Minutes']
# Out:
# 0        90
# 1         2
# 2         1
# 3         1
# 4         2
#        ...
# 8802    158
# 8803      2
# 8804     88
# 8805     88
# 8806    111
# Name: Minutes, Length: 8807, dtype: object

# %%
nf1
# Out:
#      show_id Category                  TITLE         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
nf1.head(2)
# Out:
#   show_id Category                 TITLE         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year Rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                              genre  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    YEAR  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes    units
# ...

# %%
nf1_tv=nf1[nf1['Category']=='TV Show']

# %%
nf1_tv
# Out:
#      show_id Category                  TITLE         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
nf1_tv.country.value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
nf1_tv.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %%
nf1.sort_values('YEAR')
# Out:
#      show_id Category                         TITLE              director  \
# 5957   s5958    Movie          To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show               Dinner for Five                   NaN
# 5956   s5957    Movie       Just Another Love Story          Ole Bornedal
# 5955   s5956    Movie                      Splatter             Joe Dante
# 7370   s7371    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 7196   s7197  TV Show                      Kikoriki                   NaN
# 7254   s7255  TV Show           La Familia P. Luche                   NaN
# 7406   s7407  TV Show                         Maron                   NaN
# 7847   s7848  TV Show                  Red vs. Blue                   NaN
# 8182   s8183  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    cast        country  \
# ...

# %%
nf1
# Out:
#      show_id Category                  TITLE         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
nf1.dtypes
# Out:
# show_id                 object
# Category                object
# TITLE                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# Rating                  object
# duration                object
# genre                   object
# description             object
# Date_N          datetime64[ns]
# YEAR                   float64
# Minutes                 object
# units                   object
# dtype: object

# %%
nf1.sort_values(by = 'YEAR',ascending= False).head()
# Out:
#      show_id Category                               TITLE         director  \
# 0         s1    Movie                Dick Johnson Is Dead  Kirsten Johnson
# 996     s997    Movie                          HOMUNCULUS  Takashi Shimizu
# 1005   s1006    Movie  Keymon and Nani in Space Adventure              NaN
# 1004   s1005  TV Show                  Izzy's Koala World              NaN
# 1003   s1004  TV Show                                Zero              NaN
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 996   Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...          Japan
# 1005                                                NaN            NaN
# 1004                         Izzy Bee, Ali Bee, Tim Bee      Australia
# 1003  Giuseppe Dave Seke, Haroun Fall, Beatrice Gran...          Italy
#
#               date_added  release_year Rating   duration  \
# ...

# %%
nf1[(nf1['Category']=='Movie') & (nf1['genre']=='Dramas')]
# Out:
#      show_id Category                TITLE             director  \
# 112     s113    Movie                Worth       Sara Colangelo
# 129     s130    Movie   An Unfinished Life      Lasse Hallström
# 142     s143    Movie      Freedom Writers  Richard LaGravenese
# 162     s163    Movie             Marshall      Reginald Hudlin
# 329     s330    Movie  Catch Me If You Can     Steven Spielberg
# ...      ...      ...                  ...                  ...
# 8674   s8675    Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676    Movie               Victor    Brandon Dickerson
# 8685   s8686    Movie                  VS.             Ed Lilly
# 8691   s8692    Movie            Wakefield        Robin Swicord
# 8696   s8697    Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...

# %%
(nf1['Category']=='TV Show') & (nf1['genre']=='Kids TV')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
nf1[(nf1['Category']=='TV Show') & (nf1['genre']=="Kids TV")]
# Out:
# Empty DataFrame
# Columns: [show_id, Category, TITLE, director, cast, country, date_added, release_year, Rating, duration, genre, description, Date_N, YEAR, Minutes, units]
# Index: []

# %%
nf1[(nf1['Category']=='Movie') & (nf1['genre']=='Dramas') | (nf1['Category']=='TV Show') & (nf1['genre']=="Kids TV")]
# Out:
#      show_id Category                TITLE             director  \
# 112     s113    Movie                Worth       Sara Colangelo
# 129     s130    Movie   An Unfinished Life      Lasse Hallström
# 142     s143    Movie      Freedom Writers  Richard LaGravenese
# 162     s163    Movie             Marshall      Reginald Hudlin
# 329     s330    Movie  Catch Me If You Can     Steven Spielberg
# ...      ...      ...                  ...                  ...
# 8674   s8675    Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676    Movie               Victor    Brandon Dickerson
# 8685   s8686    Movie                  VS.             Ed Lilly
# 8691   s8692    Movie            Wakefield        Robin Swicord
# 8696   s8697    Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...
